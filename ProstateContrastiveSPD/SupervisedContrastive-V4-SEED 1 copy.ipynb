# %%
import os
import numpy as np
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#os.environ["OMP_NUM_THREADS"] = str(1)

import torch
torch.set_num_threads(1)
import matplotlib.pyplot as plt
import random
SEED = 1
from sklearn.model_selection import StratifiedKFold

from Utils import EarlyStopping
from spdnetwork.optimizers import MixOptimizer
from Models import   Contrastive_CB3, MertashBiParametricNetworkV3, CB1_BiRe1, CB1_BiRe1_int1, CB1_noSPD, CB1_BiRe1_int2
from Models import Contrastive_CB3_SPD_WithOutBire, CB2_BiRe1, CB2_noSPD, CB2_BiRe1_int1, CB2_BiRe1_int2, CB3_BiRe1, CB3_noSPD, CB3_BiRe1_int1, CB3_BiRe1_int2, Contrastive_CB3_SPD_1Bire
from ProstatexDataset import ProstatexDataset
from DatasetManagement import DatasetManagement
from Losses import NTXentLoss, TripletLoss, NTXentLossLp
import json
import copy
import pandas as pd
import joblib
import math
# device = torch.device('cpu')
# device = torch.device('cuda:0')
device = 'cuda' if torch.cuda.is_available() else 'cpu'

cpu = torch.device('cpu')
#'1.3.4' pandas version
def reset_random_seeds():
    torch.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)


# %load_ext autoreload
# %autoreload 2

# %%
def get_mining_config(args):
    if args['loss_function']['mining']['positives'] is None or args['loss_function']['mining']['negatives'] is None:
        return 'no-mining'
    else:
        rules = {
            'easy': 'e',
            'hard': 'h',
            'semihard': 'sh'
        }
        mining_name ='{}p-{}n'.format(
            rules[args['loss_function']['mining']['positives']],
            rules[args['loss_function']['mining']['negatives']]
        )
        return mining_name

def get_loss_function(args):
    if args['loss_function']['kind'] == 'TripletLoss':
        loss_name = '{}_ts_ephn_m_{}'.format(
            args['loss_function']['kind'],
            args['loss_function']['margin']
        )
    elif args['loss_function']['kind'] == 'n_pair':
        loss_name = args['loss_function']['kind']

    elif args['loss_function']['kind'] == 'NTXentLoss':
        loss_name = '{}_T_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['temperature']
        )
    
    elif args['loss_function']['kind'] == 'SupervisedContrastiveLoss':
        loss_name = '{}_T_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['temperature']
        )

    elif args['loss_function']['kind'] == 'max_margin':
        loss_name = '{}_met_{}_mar_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['metric'],
            args['loss_function']['margin']
        )

    return loss_name

def get_optimizer(args):
    if args['optimizer']['kind'] == 'Mix_RMSprop':
        optimizer_name = '{}_mom_{}_lr_{}'.format(
            args['optimizer']['kind'],
            args['optimizer']['momentum'],
            args['optimizer']['learning_rate']
        )

    if args['optimizer']['kind'] == 'RMSprop':
        optimizer_name = '{}_mom_{}_lr_{}'.format(
            args['optimizer']['kind'],
            args['optimizer']['momentum'],
            args['optimizer']['learning_rate']
        )
    
    elif args['optimizer']['kind'] == 'Adam':
        optimizer_name = '{}_lr_{}'.format(
            args['optimizer']['kind'],
            args['optimizer']['learning_rate']
        )
    return optimizer_name

# %%
def fit_contrastive(model, train_data, val_data, args):
    
    train_losses = []
    val_losses = []
    early_stopping = EarlyStopping(patience=args['epochs']*0.05)
    
    if args['loss_function']['kind'] == 'NTXentLoss':
        criterion = NTXentLoss(
            temperature = args['loss_function']['temperature'],
            positives = args['loss_function']['mining']['positives'],
            negatives = args['loss_function']['mining']['negatives']
        )
    elif args['loss_function']['kind'] == 'TripletLoss':
        criterion = TripletLoss(
            margin=args['loss_function']['margin'],
            positives = args['loss_function']['mining']['positives'],
            negatives = args['loss_function']['mining']['negatives']
        )
        
    elif args['loss_function']['kind'] == 'SupervisedContrastiveLoss':
        criterion = SupervisedContrastiveLoss(
            temperature=args['loss_function']['temperature'],
        )
    
    elif args['loss_function']['kind'] == 'NTXentLossLp':
        
        criterion = NTXentLossLp(
            temperature = args['loss_function']['temperature'],
            positives = args['loss_function']['mining']['positives'],
            negatives = args['loss_function']['mining']['negatives']
        )
        print("Training with NTXentLossLp")
    
    if args['optimizer']['kind'] == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=args['optimizer']['learning_rate'])
    elif args['optimizer']['kind'] == 'RMSprop':
        optimizer = torch.optim.RMSprop(
            model.parameters(), 
            lr=args['optimizer']['learning_rate'],
            momentum = args['optimizer']['momentum']
        )
        
    elif args['optimizer']['kind'] == 'RMSprop':
        optimizer = torch.optim.RMSprop(
            model.parameters(), 
            lr=args['optimizer']['learning_rate'],
            momentum = args['optimizer']['momentum']
        )
    
    elif args['optimizer']['kind'] == 'Mix_RMSprop':
        optimizer = torch.optim.RMSprop(
            model.parameters(), 
            lr=args['optimizer']['learning_rate'],
            momentum = args['optimizer']['momentum']
        )

        optimizer = MixOptimizer(parameters = model.parameters(), 
                                optimizer = torch.optim.RMSprop,                                
                                lr = args['optimizer']['learning_rate']                             
                                )
        
    
    train_loader = torch.utils.data.DataLoader(
        dataset = train_data,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )
    val_loader = torch.utils.data.DataLoader(
        dataset = val_data,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )
    
    #train_loop
    model.train()
    model.to(device)
    model.type(torch.double)
    for epoch in range (args['epochs']):
        if early_stopping.early_stop:
            break;
        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            for j in range(len(inputs)):
                inputs[j] = inputs[j].to(device)
            labels = labels.to(device)
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(inputs)
            outputs = torch.nn.functional.normalize(outputs, p=2.0)
            loss = criterion(outputs, labels)
            # loss2 = criterion_2(model_dnn(outputs),labels)
            # loss_final = loss*1e-3 + loss2 
            loss.backward()
            optimizer.step()

            running_loss += loss.item()* inputs[0].size(0)
        
        running_loss = running_loss / len(train_data)
        train_losses.append(running_loss) 
        with torch.no_grad():
            #validation_loop
            model.eval()
            model.to(device)
            val_loss = 0.0
            for i, data in enumerate(val_loader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                for j in range(len(inputs)):
                    inputs[j] = inputs[j].to(device)
                labels = labels.to(device)
                # forward + backward + optimize
                outputs = model(inputs)
                outputs = torch.nn.functional.normalize(outputs, p=2.0)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs[0].size(0)
            val_loss = val_loss / len(val_data)
            val_losses.append(val_loss)

            early_stopping(val_loss)
            if (epoch+1) % 1 == 0: #25
                print('Epoch {}, val_loss:{:.3f}, train_loss:{:.3f}'.format(epoch+1, val_loss, running_loss ))
        
        
    return {
        'loss': train_losses,
        'val_loss': val_losses,
    }

# %%
def fit_linear_top(model, train_data):
    from sklearn.linear_model import LogisticRegression
    from sklearn.svm import SVC
    
    logistic_regressor = LogisticRegression(random_state=SEED)
    svm = SVC(kernel='linear', probability=True, random_state= SEED)
    train_loader = torch.utils.data.DataLoader(
        dataset = train_data,
        shuffle = False,
        batch_size = len(train_data),
        pin_memory=False
    )
    with torch.no_grad():
        #train_loop
        model.train()
        model.to(device)
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            #ADD
            for j in range(len(inputs)):
                inputs[j] = inputs[j].to(device)
            labels = labels.to(device)
            #----
            #print("Antes del input")
            outputs = model(inputs)
            #print("Después del input")
            outputs = torch.nn.functional.normalize(outputs, p=2.0)
            labels = torch.squeeze(labels, dim=1)

            #ADD
            outputs = outputs.cpu()
            labels = labels.cpu()
            #---
            logistic_regressor.fit(outputs.numpy(), labels.numpy())
            svm.fit(outputs.numpy(), labels.numpy())
            print("labels shape", labels.shape)
            
    print('finished linear training')
    return {
        'svm': svm, 
        'logistic_regression': logistic_regressor
    }

# %%
def evaluate(model, classifiers, test_data):
    import joblib
    
    
    
    svm = classifiers['svm']
    logistic_regressor = classifiers['logistic_regression']
    train_loader = torch.utils.data.DataLoader(
        dataset = test_data,
        shuffle = False,
        batch_size = len(test_data),
        pin_memory=False
    )
    with torch.no_grad():
        #train_loop
        model.eval()
        model.to(device)
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            #ADD
            for j in range(len(inputs)):
                inputs[j] = inputs[j].to(device)
            labels = labels.to(device)

            #---
            outputs = model(inputs)
            outputs = torch.nn.functional.normalize(outputs, p=2.0)
            #labels = torch.squeeze(labels, dim=1)
            #print("labels shape", labels.shape)
            #print("embeddings shape", outputs.shape)
            #ADD
            outputs = outputs.cpu()
            labels = labels.cpu()
            #---
            
            lr_probs = logistic_regressor.predict_proba(outputs.numpy())[:,1]
            svm_probs = svm.predict_proba(outputs.numpy())[:,1]
            
            
    print('finished linear training')
    return {
        'svm_probs': svm_probs, 
        'lr_probs': lr_probs
    }

# %%
def get_fold_of_data(kfold_number, train_data_percentage):


    if train_data_percentage is not None:
        FOLD_IDEX_PATH = '/data/json_index_shuffle.json'
        print(f'-------Cargando los datos del JSON revuelto con el {train_data_percentage*100} % en el fold {kfold_number+1}-------')
    else:
        FOLD_IDEX_PATH = '/data/picai_folds_indexes.json'
        print("^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^")
    
    fold_indexes = open(FOLD_IDEX_PATH, 'r')
    indexdes = json.load(fold_indexes)

        
    training_target_kfold = 'Fold_{}_train'.format(kfold_number)
    validation_target_kfold = 'Fold_{}_val'.format(kfold_number)

    BASE_PATH = '/data/'
    JSON_PATH = os.path.join(BASE_PATH, 'info-12x32x32.json')
    IMAGES_PATH = os.path.join(BASE_PATH, 'size-12x32x32')
    file = open(JSON_PATH, 'r')

    metadata = json.load(file)
    #file_names = os.listdir(IMAGES_PATH)

    X_train = []
    Y_train = []
    
    ids_train = []
    ids_val = []

    X_validation = []
    Y_validation = []
    
    idx_count = 0 #Contador para ir sabiendo cuantos voy cargando
    
    if train_data_percentage is not None:
        target_stop = int(train_data_percentage * len(indexdes[training_target_kfold])) #Hasta que idx voy a entrenar
        print(f"Porcentaje de entrenamiento{train_data_percentage}")
        print(f"tamaño del fold {len(indexdes[training_target_kfold])}")
    
    if train_data_percentage is not None:   
        #print("Entrenando con porcentajes")
        for patient_id in indexdes[training_target_kfold]:
            idx_count+=1
            file_name = '{}.npy'.format(patient_id)
            img = np.load(os.path.join(IMAGES_PATH, file_name))
            X_train.append(img)
            ids_train.append(patient_id)
            #print("Entrenando con porcentajes")
    
            y = metadata[patient_id]['label']
            Y_train.append(y)
            
            if idx_count == target_stop:
                break;
    else:  
        print("Entrenando sin porcentajes") 
        for patient_id in indexdes[training_target_kfold]:
            
            file_name = '{}.npy'.format(patient_id)
            img = np.load(os.path.join(IMAGES_PATH, file_name))
            X_train.append(img)
            ids_train.append(patient_id)
    
            y = metadata[patient_id]['label']
            Y_train.append(y)
        
        
    for patient_id in indexdes[validation_target_kfold]:
        file_name = '{}.npy'.format(patient_id)
        img = np.load(os.path.join(IMAGES_PATH, file_name))
        X_validation.append(img)
        ids_val.append(patient_id)

        y = metadata[patient_id]['label']
        Y_validation.append(y)
    
    print(f"Tamaño del x_train {len(X_train)}")
        
    return np.array(X_train), np.array(X_validation), np.array(Y_train), np.array(Y_validation), ids_train, ids_val, indexdes

# %%
def run_k_fold(args):
    current_fold = 0
    train_data_percentage = args['subsampling_strategy']['percentage']
    optimizer_name = get_optimizer(args)
    mining_name = get_mining_config(args)   
    base_path = '/data/Experiments/'

    if train_data_percentage is not None:
        percent_path = os.path.join(base_path, f'Experiments_with_{train_data_percentage*100}%/')
        if not os.path.exists(percent_path):
            os.makedirs(percent_path)
            
        print(f'****** Trainning with the {train_data_percentage*100}% data******')
        base_path = percent_path
        
        
    
    loss_path = os.path.join(base_path, 'losses')
    if not os.path.exists(loss_path):
        os.makedirs(loss_path)
    
    fold_number = 4
        
       
    


    best_loss = float('inf') 
    current_fold += 1
    print(f'******** Fold {current_fold} ********')

    x_train, x_validation ,y_train, y_validation, ids_train, ids_val, indexdes = get_fold_of_data(fold_number, train_data_percentage)
    train_dataset = DatasetManagement(x_train, y_train)
    val_dataset = DatasetManagement(x_validation, y_validation)
    test_dataset = val_dataset


    if train_data_percentage is not None:
        #Saving the JSON with ids selected for n%
        path_json_idx = os.path.join(base_path, f'JSONs folds')
        if not os.path.exists(path_json_idx):
            os.makedirs(path_json_idx)

        path_json_idx_plus_name = os.path.join(path_json_idx, f'JSON_idx_fold_{current_fold}')

        with open(path_json_idx_plus_name, 'w') as f:
            json.dump(indexdes, f)


    correct_fold_list = []

    for i in range (len(ids_val)):
        correct_fold_list.append('test')
            

    
    if args['backbone_name'] == 'Contrastive_CB3_SPD_1Bire':
        model = Contrastive_CB3_SPD_1Bire(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
        print('loaded Contrastive_CB3_SPD_1Bire model')
        
    if args['backbone_name'] == 'Contrastive_CB3':
        model = Contrastive_CB3(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
        print('loaded Contrastive_CB3 model')
        
    if args['backbone_name'] == 'Contrastive_CB3_SPD_WithOutBire':
        model = Contrastive_CB3_SPD_WithOutBire(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
        print('loaded Contrastive_CB3_SPD_WithOutBire model')
        
        
    history = fit_contrastive(model, train_dataset, val_dataset, args)
    validation_loss = history['val_loss'][-1]
    
    plt.plot(history['loss'], label = 'loss')
    plt.plot(history['val_loss'], label = 'val_loss')
    plt.legend()
    plt.savefig(os.path.join(loss_path, f'loss_fold_{current_fold}.png'))
    plt.show()
    plt.close() #PARA QUE NO SE SOBREPONGA
    classifiers = fit_linear_top(model, train_dataset)
    probs = evaluate(model, classifiers, test_dataset)

    directory_models = os.path.join(base_path, 'models')
    if not os.path.exists(directory_models):
        os.makedirs(directory_models)
    
    
    joblib.dump(
        classifiers['svm'],
        base_path+'models/svm_fold_{}.pkl'.format(current_fold)
    )
    joblib.dump(
        classifiers['logistic_regression'],
        base_path+'models/lr_fold_{}.pkl'.format(current_fold)
    )

    directory_results = os.path.join(base_path, 'results')
    if not os.path.exists(directory_results):
        os.makedirs(directory_results)

    kfold_dataframe = pd.DataFrame(
        {
            'indexes': ids_val,
            'folds': correct_fold_list,   
            'labels': y_validation.tolist(),
            'lr_probs': probs['lr_probs'].tolist(),
            'svm_probs': probs['svm_probs'].tolist()
        }
    )
    kfold_dataframe.to_csv('{}/results/kfold_results_{}.csv'.format(base_path, current_fold))            
    
    if validation_loss < best_loss:
        best_loss = validation_loss
        torch.save(
            model.state_dict(), 
            base_path+'models/mertash_contrastive_fold_{}.pt'.format(current_fold)
        )

# %% [markdown]
# CON PORCENTAJES

# %%
for percentage in [40]:
    
    train_data_percentage = percentage / 100
    args = {
                        'subsampling_strategy':{
                            'name': 'subsampling_criteria',
                            'percentage': train_data_percentage
                        },
                        'optimizer':{
                            'kind': 'RMSprop',
                            'learning_rate': 1e-6,
                            'momentum': 0.6
                        },
                        'loss_function': {
                                'kind': 'TripletLoss',
                                'margin': 0.05,
                                'temperature': 0.07,
                                'mining': {
                                    'positives': 'easy',
                                    'negatives': 'semihard'
                                }
                        },
                        'number_folds': 5,
                        'backbone_name': 'Contrastive_CB3',
                        'data': 'mertash',
                        'sequence_embedding_features': 18432,
                        'target_shape': (12, 32, 32),
                        'batch_size': 32,
                        'epochs': 1500,
                    }
    run_k_fold(args)
# Out:
# ****** Trainning with the 40.0% data******
# ******** Fold 1 ********
# -------Cargando los datos del JSON revuelto con el 40.0 % en el fold 5-------
# Porcentaje de entrenamiento0.4
# tamaño del fold 1043
# Tamaño del x_train 417
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.048, train_loss:0.028
# Epoch 2, val_loss:0.047, train_loss:0.047
# Epoch 3, val_loss:0.046, train_loss:0.046
# Epoch 4, val_loss:0.045, train_loss:0.044
# Epoch 5, val_loss:0.042, train_loss:0.042
# Epoch 6, val_loss:0.040, train_loss:0.042
# Epoch 7, val_loss:0.039, train_loss:0.041
# Epoch 8, val_loss:0.038, train_loss:0.039
# Epoch 9, val_loss:0.035, train_loss:0.037
# Epoch 10, val_loss:0.031, train_loss:0.034
# Epoch 11, val_loss:0.030, train_loss:0.031
# Epoch 12, val_loss:0.029, train_loss:0.028
# Epoch 13, val_loss:0.031, train_loss:0.028
# Epoch 14, val_loss:0.032, train_loss:0.031
# Epoch 15, val_loss:0.027, train_loss:0.027
# Epoch 16, val_loss:0.028, train_loss:0.028
# Epoch 17, val_loss:0.032, train_loss:0.027
# Epoch 18, val_loss:0.030, train_loss:0.026
# Epoch 19, val_loss:0.027, train_loss:0.027
# Epoch 20, val_loss:0.031, train_loss:0.030
# Epoch 21, val_loss:0.032, train_loss:0.026
# Epoch 22, val_loss:0.025, train_loss:0.028
# Epoch 23, val_loss:0.028, train_loss:0.025
# Epoch 24, val_loss:0.030, train_loss:0.027
# Epoch 25, val_loss:0.030, train_loss:0.025
# Epoch 26, val_loss:0.029, train_loss:0.024
# Epoch 27, val_loss:0.030, train_loss:0.024
# Epoch 28, val_loss:0.033, train_loss:0.028
# Epoch 29, val_loss:0.030, train_loss:0.028
# Epoch 30, val_loss:0.026, train_loss:0.024
# Epoch 31, val_loss:0.031, train_loss:0.023
# Epoch 32, val_loss:0.027, train_loss:0.023
# Epoch 33, val_loss:0.023, train_loss:0.023
# Epoch 34, val_loss:0.036, train_loss:0.033
# Epoch 35, val_loss:0.033, train_loss:0.034
# Epoch 36, val_loss:0.030, train_loss:0.031
# Epoch 37, val_loss:0.030, train_loss:0.024
# Epoch 38, val_loss:0.033, train_loss:0.028
# Epoch 39, val_loss:0.028, train_loss:0.024
# Epoch 40, val_loss:0.028, train_loss:0.027
# Epoch 41, val_loss:0.029, train_loss:0.023
# Epoch 42, val_loss:0.031, train_loss:0.025
# Epoch 43, val_loss:0.028, train_loss:0.027
# Epoch 44, val_loss:0.031, train_loss:0.024
# Epoch 45, val_loss:0.028, train_loss:0.024
# Epoch 46, val_loss:0.028, train_loss:0.025
# Epoch 47, val_loss:0.027, train_loss:0.025
# Epoch 48, val_loss:0.032, train_loss:0.026
# Epoch 49, val_loss:0.031, train_loss:0.028
# Epoch 50, val_loss:0.027, train_loss:0.024
# Epoch 51, val_loss:0.027, train_loss:0.025
# Epoch 52, val_loss:0.028, train_loss:0.023
# Epoch 53, val_loss:0.033, train_loss:0.021
# Epoch 54, val_loss:0.029, train_loss:0.025
# Epoch 55, val_loss:0.027, train_loss:0.021
# Epoch 56, val_loss:0.029, train_loss:0.021
# Epoch 57, val_loss:0.031, train_loss:0.028
# Epoch 58, val_loss:0.031, train_loss:0.025
# Epoch 59, val_loss:0.030, train_loss:0.024
# Epoch 60, val_loss:0.033, train_loss:0.024
# Epoch 61, val_loss:0.029, train_loss:0.021
# Epoch 62, val_loss:0.029, train_loss:0.023
# Epoch 63, val_loss:0.029, train_loss:0.021
# Epoch 64, val_loss:0.031, train_loss:0.023
# Epoch 65, val_loss:0.031, train_loss:0.019
# Epoch 66, val_loss:0.029, train_loss:0.023
# Epoch 67, val_loss:0.031, train_loss:0.027
# Epoch 68, val_loss:0.029, train_loss:0.025
# Epoch 69, val_loss:0.027, train_loss:0.022
# Epoch 70, val_loss:0.032, train_loss:0.027
# Epoch 71, val_loss:0.031, train_loss:0.027
# Epoch 72, val_loss:0.030, train_loss:0.022
# Epoch 73, val_loss:0.029, train_loss:0.022
# Epoch 74, val_loss:0.029, train_loss:0.021
# Epoch 75, val_loss:0.030, train_loss:0.023
# Epoch 76, val_loss:0.030, train_loss:0.023
# Epoch 77, val_loss:0.027, train_loss:0.023
# Epoch 78, val_loss:0.029, train_loss:0.020
# Epoch 79, val_loss:0.031, train_loss:0.030
# Epoch 80, val_loss:0.031, train_loss:0.028
# Epoch 81, val_loss:0.027, train_loss:0.025
# Epoch 82, val_loss:0.029, train_loss:0.021
# Epoch 83, val_loss:0.029, train_loss:0.021
# Epoch 84, val_loss:0.028, train_loss:0.020
# Epoch 85, val_loss:0.026, train_loss:0.024
# Epoch 86, val_loss:0.028, train_loss:0.020
# Epoch 87, val_loss:0.031, train_loss:0.022
# Epoch 88, val_loss:0.029, train_loss:0.021
# Epoch 89, val_loss:0.030, train_loss:0.019
# Epoch 90, val_loss:0.028, train_loss:0.021
# Epoch 91, val_loss:0.030, train_loss:0.023
# Epoch 92, val_loss:0.030, train_loss:0.020
# Epoch 93, val_loss:0.028, train_loss:0.026
# Epoch 94, val_loss:0.028, train_loss:0.021
# Epoch 95, val_loss:0.029, train_loss:0.018
# Epoch 96, val_loss:0.028, train_loss:0.020
# Epoch 97, val_loss:0.029, train_loss:0.018
# Epoch 98, val_loss:0.030, train_loss:0.027
# Epoch 99, val_loss:0.028, train_loss:0.021
# Epoch 100, val_loss:0.030, train_loss:0.017
# Epoch 101, val_loss:0.032, train_loss:0.019
# Epoch 102, val_loss:0.028, train_loss:0.017
# Epoch 103, val_loss:0.033, train_loss:0.020
# Epoch 104, val_loss:0.028, train_loss:0.024
# Epoch 105, val_loss:0.031, train_loss:0.017
# Epoch 106, val_loss:0.028, train_loss:0.017
# Epoch 107, val_loss:0.029, train_loss:0.019
# INFO: Early stopping
# Epoch 108, val_loss:0.028, train_loss:0.018
# labels shape torch.Size([417])
# finished linear training
# finished linear training

# %% [markdown]
# SIN PORCENTAJES

# %%
args = {
                'subsampling_strategy':{
                    'name': 'subsampling_criteria',
                    'percentage': None
                },
                'optimizer':{
                    'kind': 'RMSprop',
                    'learning_rate': 1e-6,
                    'momentum': 0.6
                },
                'loss_function': {
                        'kind': 'TripletLoss',
                        'margin': 0.05,
                        'temperature': 0.07,
                        'mining': {
                            'positives': 'easy',
                            'negatives': 'semihard'
                        }
                },
                'number_folds': 5,
                'backbone_name': 'Contrastive_CB3',
                'data': 'mertash',
                'sequence_embedding_features': 18432, #Para SPD TS 2080, para solo AC: 18432
                'target_shape': (12, 32, 32),
                'batch_size': 32,
                'epochs': 1500,
                    }
run_k_fold(args)
# Out:
# ******** Fold 1 ********
# ^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^
# Entrenando sin porcentajes
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.030, train_loss:0.027
# Epoch 2, val_loss:0.025, train_loss:0.028
# Epoch 3, val_loss:0.028, train_loss:0.026
# Epoch 4, val_loss:0.028, train_loss:0.024
# Epoch 5, val_loss:0.025, train_loss:0.024
# Epoch 6, val_loss:0.026, train_loss:0.023
# Epoch 7, val_loss:0.027, train_loss:0.019
# Epoch 8, val_loss:0.025, train_loss:0.023
# Epoch 9, val_loss:0.027, train_loss:0.022
# Epoch 10, val_loss:0.024, train_loss:0.021
# Epoch 11, val_loss:0.023, train_loss:0.015
# Epoch 12, val_loss:0.028, train_loss:0.015
# Epoch 13, val_loss:0.027, train_loss:0.015
# Epoch 14, val_loss:0.027, train_loss:0.013
# Epoch 15, val_loss:0.021, train_loss:0.011
# Epoch 16, val_loss:0.026, train_loss:0.016
# Epoch 17, val_loss:0.029, train_loss:0.012
# Epoch 18, val_loss:0.025, train_loss:0.012
# Epoch 19, val_loss:0.030, train_loss:0.009
# Epoch 20, val_loss:0.026, train_loss:0.014
# Epoch 21, val_loss:0.027, train_loss:0.006
# Epoch 22, val_loss:0.027, train_loss:0.010
# Epoch 23, val_loss:0.027, train_loss:0.007
# Epoch 24, val_loss:0.027, train_loss:0.007
# Epoch 25, val_loss:0.030, train_loss:0.008
# Epoch 26, val_loss:0.029, train_loss:0.005
# Epoch 27, val_loss:0.027, train_loss:0.003
# Epoch 28, val_loss:0.027, train_loss:0.005
# Epoch 29, val_loss:0.026, train_loss:0.002
# Epoch 30, val_loss:0.029, train_loss:0.006
# Epoch 31, val_loss:0.030, train_loss:0.006
# Epoch 32, val_loss:0.028, train_loss:0.007
# Epoch 33, val_loss:0.027, train_loss:0.008
# Epoch 34, val_loss:0.027, train_loss:0.006
# Epoch 35, val_loss:0.024, train_loss:0.002
# Epoch 36, val_loss:0.027, train_loss:0.004
# Epoch 37, val_loss:0.026, train_loss:0.003
# Epoch 38, val_loss:0.024, train_loss:0.006
# Epoch 39, val_loss:0.027, train_loss:0.005
# Epoch 40, val_loss:0.025, train_loss:0.005
# Epoch 41, val_loss:0.024, train_loss:0.006
# Epoch 42, val_loss:0.022, train_loss:0.004
# Epoch 43, val_loss:0.027, train_loss:0.003
# Epoch 44, val_loss:0.026, train_loss:0.000
# Epoch 45, val_loss:0.027, train_loss:0.002
# Epoch 46, val_loss:0.026, train_loss:0.003
# Epoch 47, val_loss:0.026, train_loss:0.001
# Epoch 48, val_loss:0.026, train_loss:0.002
# Epoch 49, val_loss:0.027, train_loss:0.001
# Epoch 50, val_loss:0.027, train_loss:0.003
# Epoch 51, val_loss:0.026, train_loss:0.000
# Epoch 52, val_loss:0.025, train_loss:0.002
# Epoch 53, val_loss:0.025, train_loss:0.003
# Epoch 54, val_loss:0.025, train_loss:0.003
# Epoch 55, val_loss:0.026, train_loss:0.003
# Epoch 56, val_loss:0.025, train_loss:0.002
# Epoch 57, val_loss:0.027, train_loss:0.000
# Epoch 58, val_loss:0.028, train_loss:0.004
# Epoch 59, val_loss:0.027, train_loss:0.002
# Epoch 60, val_loss:0.027, train_loss:0.000
# Epoch 61, val_loss:0.027, train_loss:0.000
# Epoch 62, val_loss:0.027, train_loss:0.000
# Epoch 63, val_loss:0.027, train_loss:0.000
# Epoch 64, val_loss:0.027, train_loss:0.000
# Epoch 65, val_loss:0.027, train_loss:0.000
# Epoch 66, val_loss:0.027, train_loss:0.000
# Epoch 67, val_loss:0.027, train_loss:0.000
# Epoch 68, val_loss:0.027, train_loss:0.000
# Epoch 69, val_loss:0.027, train_loss:0.000
# Epoch 70, val_loss:0.027, train_loss:0.000
# Epoch 71, val_loss:0.027, train_loss:0.000
# Epoch 72, val_loss:0.027, train_loss:0.000
# Epoch 73, val_loss:0.027, train_loss:0.000
# Epoch 74, val_loss:0.027, train_loss:0.000
# Epoch 75, val_loss:0.027, train_loss:0.000
# Epoch 76, val_loss:0.027, train_loss:0.000
# Epoch 77, val_loss:0.027, train_loss:0.000
# Epoch 78, val_loss:0.027, train_loss:0.000
# Epoch 79, val_loss:0.027, train_loss:0.000
# Epoch 80, val_loss:0.027, train_loss:0.000
# Epoch 81, val_loss:0.027, train_loss:0.000
# Epoch 82, val_loss:0.027, train_loss:0.000
# Epoch 83, val_loss:0.027, train_loss:0.000
# Epoch 84, val_loss:0.027, train_loss:0.000
# Epoch 85, val_loss:0.027, train_loss:0.000
# Epoch 86, val_loss:0.027, train_loss:0.000
# Epoch 87, val_loss:0.027, train_loss:0.000
# Epoch 88, val_loss:0.027, train_loss:0.000
# Epoch 89, val_loss:0.027, train_loss:0.000
# INFO: Early stopping
# Epoch 90, val_loss:0.027, train_loss:0.000
# labels shape torch.Size([1035])
# finished linear training
# finished linear training
# ******** Fold 2 ********
# ^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^
# Entrenando sin porcentajes
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.036, train_loss:0.028
# Epoch 2, val_loss:0.027, train_loss:0.030
# Epoch 3, val_loss:0.027, train_loss:0.027
# Epoch 4, val_loss:0.027, train_loss:0.028
# Epoch 5, val_loss:0.028, train_loss:0.025
# Epoch 6, val_loss:0.028, train_loss:0.027
# Epoch 7, val_loss:0.028, train_loss:0.024
# Epoch 8, val_loss:0.028, train_loss:0.023
# Epoch 9, val_loss:0.029, train_loss:0.022
# Epoch 10, val_loss:0.028, train_loss:0.023
# Epoch 11, val_loss:0.028, train_loss:0.021
# Epoch 12, val_loss:0.030, train_loss:0.021
# Epoch 13, val_loss:0.026, train_loss:0.022
# Epoch 14, val_loss:0.031, train_loss:0.018
# Epoch 15, val_loss:0.029, train_loss:0.019
# Epoch 16, val_loss:0.027, train_loss:0.018
# Epoch 17, val_loss:0.026, train_loss:0.017
# Epoch 18, val_loss:0.032, train_loss:0.017
# Epoch 19, val_loss:0.029, train_loss:0.018
# Epoch 20, val_loss:0.029, train_loss:0.015
# Epoch 21, val_loss:0.026, train_loss:0.015
# Epoch 22, val_loss:0.029, train_loss:0.017
# Epoch 23, val_loss:0.030, train_loss:0.015
# Epoch 24, val_loss:0.024, train_loss:0.016
# Epoch 25, val_loss:0.030, train_loss:0.012
# Epoch 26, val_loss:0.029, train_loss:0.014
# Epoch 27, val_loss:0.030, train_loss:0.011
# Epoch 28, val_loss:0.029, train_loss:0.014
# Epoch 29, val_loss:0.026, train_loss:0.014
# Epoch 30, val_loss:0.029, train_loss:0.012
# Epoch 31, val_loss:0.028, train_loss:0.014
# Epoch 32, val_loss:0.030, train_loss:0.011
# Epoch 33, val_loss:0.027, train_loss:0.012
# Epoch 34, val_loss:0.026, train_loss:0.011
# Epoch 35, val_loss:0.025, train_loss:0.012
# Epoch 36, val_loss:0.028, train_loss:0.010
# Epoch 37, val_loss:0.028, train_loss:0.013
# Epoch 38, val_loss:0.024, train_loss:0.010
# Epoch 39, val_loss:0.027, train_loss:0.009
# Epoch 40, val_loss:0.026, train_loss:0.008
# Epoch 41, val_loss:0.026, train_loss:0.008
# Epoch 42, val_loss:0.029, train_loss:0.011
# Epoch 43, val_loss:0.028, train_loss:0.006
# Epoch 44, val_loss:0.028, train_loss:0.007
# Epoch 45, val_loss:0.028, train_loss:0.006
# Epoch 46, val_loss:0.029, train_loss:0.008
# Epoch 47, val_loss:0.029, train_loss:0.006
# Epoch 48, val_loss:0.029, train_loss:0.006
# Epoch 49, val_loss:0.029, train_loss:0.007
# Epoch 50, val_loss:0.030, train_loss:0.006
# Epoch 51, val_loss:0.030, train_loss:0.007
# Epoch 52, val_loss:0.030, train_loss:0.006
# Epoch 53, val_loss:0.027, train_loss:0.004
# Epoch 54, val_loss:0.026, train_loss:0.006
# Epoch 55, val_loss:0.032, train_loss:0.008
# Epoch 56, val_loss:0.029, train_loss:0.004
# Epoch 57, val_loss:0.026, train_loss:0.005
# Epoch 58, val_loss:0.031, train_loss:0.004
# Epoch 59, val_loss:0.027, train_loss:0.006
# Epoch 60, val_loss:0.030, train_loss:0.004
# Epoch 61, val_loss:0.029, train_loss:0.005
# Epoch 62, val_loss:0.033, train_loss:0.003
# Epoch 63, val_loss:0.028, train_loss:0.005
# Epoch 64, val_loss:0.030, train_loss:0.005
# Epoch 65, val_loss:0.028, train_loss:0.006
# Epoch 66, val_loss:0.029, train_loss:0.002
# Epoch 67, val_loss:0.024, train_loss:0.003
# Epoch 68, val_loss:0.029, train_loss:0.002
# Epoch 69, val_loss:0.029, train_loss:0.007
# Epoch 70, val_loss:0.032, train_loss:0.003
# Epoch 71, val_loss:0.033, train_loss:0.000
# Epoch 72, val_loss:0.032, train_loss:0.000
# Epoch 73, val_loss:0.032, train_loss:0.000
# Epoch 74, val_loss:0.032, train_loss:0.000
# Epoch 75, val_loss:0.032, train_loss:0.000
# Epoch 76, val_loss:0.032, train_loss:0.000
# Epoch 77, val_loss:0.032, train_loss:0.000
# Epoch 78, val_loss:0.032, train_loss:0.000
# Epoch 79, val_loss:0.032, train_loss:0.000
# Epoch 80, val_loss:0.032, train_loss:0.000
# Epoch 81, val_loss:0.032, train_loss:0.000
# Epoch 82, val_loss:0.032, train_loss:0.000
# Epoch 83, val_loss:0.032, train_loss:0.000
# Epoch 84, val_loss:0.032, train_loss:0.000
# Epoch 85, val_loss:0.032, train_loss:0.000
# Epoch 86, val_loss:0.032, train_loss:0.000
# Epoch 87, val_loss:0.032, train_loss:0.000
# Epoch 88, val_loss:0.032, train_loss:0.000
# Epoch 89, val_loss:0.032, train_loss:0.000
# Epoch 90, val_loss:0.032, train_loss:0.000
# Epoch 91, val_loss:0.032, train_loss:0.000
# Epoch 92, val_loss:0.032, train_loss:0.000
# Epoch 93, val_loss:0.032, train_loss:0.000
# Epoch 94, val_loss:0.032, train_loss:0.000
# Epoch 95, val_loss:0.032, train_loss:0.000
# Epoch 96, val_loss:0.032, train_loss:0.000
# Epoch 97, val_loss:0.032, train_loss:0.000
# Epoch 98, val_loss:0.032, train_loss:0.000
# Epoch 99, val_loss:0.032, train_loss:0.000
# Epoch 100, val_loss:0.032, train_loss:0.000
# Epoch 101, val_loss:0.032, train_loss:0.000
# Epoch 102, val_loss:0.032, train_loss:0.000
# Epoch 103, val_loss:0.032, train_loss:0.000
# Epoch 104, val_loss:0.032, train_loss:0.000
# Epoch 105, val_loss:0.032, train_loss:0.000
# Epoch 106, val_loss:0.032, train_loss:0.000
# Epoch 107, val_loss:0.032, train_loss:0.000
# Epoch 108, val_loss:0.032, train_loss:0.000
# Epoch 109, val_loss:0.032, train_loss:0.000
# Epoch 110, val_loss:0.032, train_loss:0.000
# Epoch 111, val_loss:0.032, train_loss:0.000
# Epoch 112, val_loss:0.032, train_loss:0.000
# INFO: Early stopping
# Epoch 113, val_loss:0.032, train_loss:0.000
# labels shape torch.Size([1031])
# finished linear training
# finished linear training
# ******** Fold 3 ********
# ^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^
# Entrenando sin porcentajes
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.039, train_loss:0.028
# Epoch 2, val_loss:0.028, train_loss:0.030
# Epoch 3, val_loss:0.025, train_loss:0.027
# Epoch 4, val_loss:0.024, train_loss:0.026
# Epoch 5, val_loss:0.025, train_loss:0.025
# Epoch 6, val_loss:0.028, train_loss:0.023
# Epoch 7, val_loss:0.025, train_loss:0.024
# Epoch 8, val_loss:0.024, train_loss:0.020
# Epoch 9, val_loss:0.025, train_loss:0.020
# Epoch 10, val_loss:0.027, train_loss:0.022
# Epoch 11, val_loss:0.024, train_loss:0.022
# Epoch 12, val_loss:0.027, train_loss:0.017
# Epoch 13, val_loss:0.026, train_loss:0.020
# Epoch 14, val_loss:0.024, train_loss:0.014
# Epoch 15, val_loss:0.025, train_loss:0.013
# Epoch 16, val_loss:0.025, train_loss:0.014
# Epoch 17, val_loss:0.026, train_loss:0.016
# Epoch 18, val_loss:0.024, train_loss:0.014
# Epoch 19, val_loss:0.025, train_loss:0.011
# Epoch 20, val_loss:0.030, train_loss:0.013
# Epoch 21, val_loss:0.025, train_loss:0.011
# Epoch 22, val_loss:0.024, train_loss:0.013
# Epoch 23, val_loss:0.029, train_loss:0.010
# Epoch 24, val_loss:0.024, train_loss:0.011
# Epoch 25, val_loss:0.023, train_loss:0.012
# Epoch 26, val_loss:0.027, train_loss:0.011
# Epoch 27, val_loss:0.024, train_loss:0.010
# Epoch 28, val_loss:0.029, train_loss:0.009
# Epoch 29, val_loss:0.026, train_loss:0.007
# Epoch 30, val_loss:0.026, train_loss:0.010
# Epoch 31, val_loss:0.022, train_loss:0.009
# Epoch 32, val_loss:0.025, train_loss:0.008
# Epoch 33, val_loss:0.027, train_loss:0.006
# Epoch 34, val_loss:0.023, train_loss:0.004
# Epoch 35, val_loss:0.029, train_loss:0.009
# Epoch 36, val_loss:0.029, train_loss:0.005
# Epoch 37, val_loss:0.026, train_loss:0.006
# Epoch 38, val_loss:0.023, train_loss:0.006
# Epoch 39, val_loss:0.028, train_loss:0.006
# Epoch 40, val_loss:0.026, train_loss:0.005
# Epoch 41, val_loss:0.025, train_loss:0.006
# Epoch 42, val_loss:0.027, train_loss:0.003
# Epoch 43, val_loss:0.025, train_loss:0.006
# Epoch 44, val_loss:0.030, train_loss:0.006
# Epoch 45, val_loss:0.027, train_loss:0.008
# Epoch 46, val_loss:0.028, train_loss:0.001
# Epoch 47, val_loss:0.026, train_loss:0.003
# Epoch 48, val_loss:0.025, train_loss:0.004
# Epoch 49, val_loss:0.030, train_loss:0.002
# Epoch 50, val_loss:0.029, train_loss:0.005
# Epoch 51, val_loss:0.029, train_loss:0.003
# Epoch 52, val_loss:0.026, train_loss:0.002
# Epoch 53, val_loss:0.023, train_loss:0.002
# Epoch 54, val_loss:0.024, train_loss:0.000
# Epoch 55, val_loss:0.025, train_loss:0.000
# Epoch 56, val_loss:0.025, train_loss:0.000
# Epoch 57, val_loss:0.025, train_loss:0.000
# Epoch 58, val_loss:0.025, train_loss:0.000
# Epoch 59, val_loss:0.025, train_loss:0.000
# Epoch 60, val_loss:0.025, train_loss:0.000
# Epoch 61, val_loss:0.025, train_loss:0.000
# Epoch 62, val_loss:0.025, train_loss:0.000
# Epoch 63, val_loss:0.025, train_loss:0.000
# Epoch 64, val_loss:0.025, train_loss:0.000
# Epoch 65, val_loss:0.025, train_loss:0.000
# Epoch 66, val_loss:0.025, train_loss:0.000
# Epoch 67, val_loss:0.025, train_loss:0.000
# Epoch 68, val_loss:0.025, train_loss:0.000
# Epoch 69, val_loss:0.025, train_loss:0.000
# Epoch 70, val_loss:0.025, train_loss:0.000
# Epoch 71, val_loss:0.025, train_loss:0.000
# Epoch 72, val_loss:0.025, train_loss:0.000
# Epoch 73, val_loss:0.025, train_loss:0.000
# Epoch 74, val_loss:0.025, train_loss:0.000
# Epoch 75, val_loss:0.025, train_loss:0.000
# Epoch 76, val_loss:0.025, train_loss:0.000
# Epoch 77, val_loss:0.025, train_loss:0.000
# Epoch 78, val_loss:0.025, train_loss:0.000
# Epoch 79, val_loss:0.025, train_loss:0.000
# Epoch 80, val_loss:0.025, train_loss:0.000
# Epoch 81, val_loss:0.025, train_loss:0.000
# Epoch 82, val_loss:0.025, train_loss:0.000
# Epoch 83, val_loss:0.025, train_loss:0.000
# Epoch 84, val_loss:0.025, train_loss:0.000
# Epoch 85, val_loss:0.025, train_loss:0.000
# Epoch 86, val_loss:0.025, train_loss:0.000
# Epoch 87, val_loss:0.025, train_loss:0.000
# Epoch 88, val_loss:0.025, train_loss:0.000
# Epoch 89, val_loss:0.025, train_loss:0.000
# Epoch 90, val_loss:0.025, train_loss:0.000
# Epoch 91, val_loss:0.025, train_loss:0.000
# Epoch 92, val_loss:0.025, train_loss:0.000
# Epoch 93, val_loss:0.025, train_loss:0.000
# Epoch 94, val_loss:0.025, train_loss:0.000
# Epoch 95, val_loss:0.025, train_loss:0.000
# Epoch 96, val_loss:0.025, train_loss:0.000
# Epoch 97, val_loss:0.025, train_loss:0.000
# Epoch 98, val_loss:0.025, train_loss:0.000
# Epoch 99, val_loss:0.025, train_loss:0.000
# Epoch 100, val_loss:0.025, train_loss:0.000
# Epoch 101, val_loss:0.025, train_loss:0.000
# Epoch 102, val_loss:0.025, train_loss:0.000
# Epoch 103, val_loss:0.025, train_loss:0.000
# Epoch 104, val_loss:0.025, train_loss:0.000
# Epoch 105, val_loss:0.025, train_loss:0.000
# INFO: Early stopping
# Epoch 106, val_loss:0.025, train_loss:0.000
# labels shape torch.Size([1041])
# finished linear training
# finished linear training
# ******** Fold 4 ********
# ^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^
# Entrenando sin porcentajes
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.031, train_loss:0.027
# Epoch 2, val_loss:0.027, train_loss:0.028
# Epoch 3, val_loss:0.026, train_loss:0.027
# Epoch 4, val_loss:0.023, train_loss:0.025
# Epoch 5, val_loss:0.025, train_loss:0.023
# Epoch 6, val_loss:0.023, train_loss:0.022
# Epoch 7, val_loss:0.023, train_loss:0.021
# Epoch 8, val_loss:0.030, train_loss:0.022
# Epoch 9, val_loss:0.027, train_loss:0.023
# Epoch 10, val_loss:0.023, train_loss:0.021
# Epoch 11, val_loss:0.023, train_loss:0.020
# Epoch 12, val_loss:0.022, train_loss:0.021
# Epoch 13, val_loss:0.021, train_loss:0.017
# Epoch 14, val_loss:0.023, train_loss:0.016
# Epoch 15, val_loss:0.026, train_loss:0.016
# Epoch 16, val_loss:0.030, train_loss:0.019
# Epoch 17, val_loss:0.026, train_loss:0.017
# Epoch 18, val_loss:0.030, train_loss:0.018
# Epoch 19, val_loss:0.025, train_loss:0.017
# Epoch 20, val_loss:0.030, train_loss:0.014
# Epoch 21, val_loss:0.033, train_loss:0.016
# Epoch 22, val_loss:0.031, train_loss:0.015
# Epoch 23, val_loss:0.031, train_loss:0.016
# Epoch 24, val_loss:0.025, train_loss:0.015
# Epoch 25, val_loss:0.028, train_loss:0.016
# Epoch 26, val_loss:0.028, train_loss:0.017
# Epoch 27, val_loss:0.029, train_loss:0.013
# Epoch 28, val_loss:0.028, train_loss:0.015
# Epoch 29, val_loss:0.027, train_loss:0.012
# Epoch 30, val_loss:0.031, train_loss:0.013
# Epoch 31, val_loss:0.029, train_loss:0.016
# Epoch 32, val_loss:0.030, train_loss:0.011
# Epoch 33, val_loss:0.026, train_loss:0.012
# Epoch 34, val_loss:0.030, train_loss:0.012
# Epoch 35, val_loss:0.031, train_loss:0.012
# Epoch 36, val_loss:0.032, train_loss:0.010
# Epoch 37, val_loss:0.030, train_loss:0.010
# Epoch 38, val_loss:0.029, train_loss:0.010
# Epoch 39, val_loss:0.033, train_loss:0.011
# Epoch 40, val_loss:0.031, train_loss:0.009
# Epoch 41, val_loss:0.033, train_loss:0.007
# Epoch 42, val_loss:0.031, train_loss:0.006
# Epoch 43, val_loss:0.029, train_loss:0.007
# Epoch 44, val_loss:0.028, train_loss:0.008
# Epoch 45, val_loss:0.031, train_loss:0.010
# Epoch 46, val_loss:0.032, train_loss:0.010
# Epoch 47, val_loss:0.026, train_loss:0.008
# Epoch 48, val_loss:0.029, train_loss:0.007
# Epoch 49, val_loss:0.032, train_loss:0.004
# Epoch 50, val_loss:0.028, train_loss:0.003
# Epoch 51, val_loss:0.028, train_loss:0.003
# Epoch 52, val_loss:0.028, train_loss:0.005
# Epoch 53, val_loss:0.030, train_loss:0.004
# Epoch 54, val_loss:0.031, train_loss:0.005
# Epoch 55, val_loss:0.029, train_loss:0.008
# Epoch 56, val_loss:0.027, train_loss:0.004
# Epoch 57, val_loss:0.028, train_loss:0.007
# Epoch 58, val_loss:0.030, train_loss:0.007
# Epoch 59, val_loss:0.027, train_loss:0.002
# Epoch 60, val_loss:0.027, train_loss:0.005
# Epoch 61, val_loss:0.027, train_loss:0.005
# Epoch 62, val_loss:0.029, train_loss:0.005
# Epoch 63, val_loss:0.032, train_loss:0.005
# Epoch 64, val_loss:0.029, train_loss:0.004
# Epoch 65, val_loss:0.028, train_loss:0.005
# Epoch 66, val_loss:0.031, train_loss:0.006
# Epoch 67, val_loss:0.032, train_loss:0.004
# Epoch 68, val_loss:0.033, train_loss:0.005
# Epoch 69, val_loss:0.030, train_loss:0.007
# Epoch 70, val_loss:0.031, train_loss:0.004
# Epoch 71, val_loss:0.031, train_loss:0.005
# Epoch 72, val_loss:0.028, train_loss:0.007
# Epoch 73, val_loss:0.032, train_loss:0.004
# Epoch 74, val_loss:0.029, train_loss:0.004
# Epoch 75, val_loss:0.029, train_loss:0.003
# Epoch 76, val_loss:0.025, train_loss:0.007
# Epoch 77, val_loss:0.026, train_loss:0.001
# Epoch 78, val_loss:0.028, train_loss:0.005
# Epoch 79, val_loss:0.029, train_loss:0.003
# Epoch 80, val_loss:0.030, train_loss:0.004
# Epoch 81, val_loss:0.029, train_loss:0.005
# Epoch 82, val_loss:0.027, train_loss:0.006
# Epoch 83, val_loss:0.028, train_loss:0.003
# Epoch 84, val_loss:0.027, train_loss:0.004
# Epoch 85, val_loss:0.030, train_loss:0.003
# Epoch 86, val_loss:0.028, train_loss:0.002
# Epoch 87, val_loss:0.030, train_loss:0.003
# INFO: Early stopping
# Epoch 88, val_loss:0.030, train_loss:0.004
# labels shape torch.Size([1030])
# finished linear training
# finished linear training
# ******** Fold 5 ********
# ^^^^^^^^^^Entrenando con todo el Dataset^^^^^^^^^^
# Entrenando sin porcentajes
# loaded Contrastive_CB3 model
# Epoch 1, val_loss:0.037, train_loss:0.026
# Epoch 2, val_loss:0.028, train_loss:0.035
# Epoch 3, val_loss:0.030, train_loss:0.028
# Epoch 4, val_loss:0.030, train_loss:0.028
# Epoch 5, val_loss:0.030, train_loss:0.027
# Epoch 6, val_loss:0.029, train_loss:0.027
# Epoch 7, val_loss:0.029, train_loss:0.027
# Epoch 8, val_loss:0.027, train_loss:0.025
# Epoch 9, val_loss:0.030, train_loss:0.025
# Epoch 10, val_loss:0.028, train_loss:0.024
# Epoch 11, val_loss:0.028, train_loss:0.023
# Epoch 12, val_loss:0.029, train_loss:0.027
# Epoch 13, val_loss:0.028, train_loss:0.025
# Epoch 14, val_loss:0.029, train_loss:0.026
# Epoch 15, val_loss:0.031, train_loss:0.027
# Epoch 16, val_loss:0.030, train_loss:0.025
# Epoch 17, val_loss:0.032, train_loss:0.022
# Epoch 18, val_loss:0.031, train_loss:0.024
# Epoch 19, val_loss:0.032, train_loss:0.023
# Epoch 20, val_loss:0.032, train_loss:0.020
# Epoch 21, val_loss:0.028, train_loss:0.023
# Epoch 22, val_loss:0.027, train_loss:0.023
# Epoch 23, val_loss:0.029, train_loss:0.020
# Epoch 24, val_loss:0.028, train_loss:0.021
# Epoch 25, val_loss:0.027, train_loss:0.019
# Epoch 26, val_loss:0.029, train_loss:0.019
# Epoch 27, val_loss:0.030, train_loss:0.015
# Epoch 28, val_loss:0.029, train_loss:0.013
# Epoch 29, val_loss:0.029, train_loss:0.017
# Epoch 30, val_loss:0.027, train_loss:0.013
# Epoch 31, val_loss:0.027, train_loss:0.013
# Epoch 32, val_loss:0.027, train_loss:0.016
# Epoch 33, val_loss:0.024, train_loss:0.015
# Epoch 34, val_loss:0.029, train_loss:0.013
# Epoch 35, val_loss:0.028, train_loss:0.018
# Epoch 36, val_loss:0.028, train_loss:0.014
# Epoch 37, val_loss:0.029, train_loss:0.013
# Epoch 38, val_loss:0.031, train_loss:0.014
# Epoch 39, val_loss:0.031, train_loss:0.013
# Epoch 40, val_loss:0.029, train_loss:0.013
# Epoch 41, val_loss:0.032, train_loss:0.013
# Epoch 42, val_loss:0.032, train_loss:0.012
# Epoch 43, val_loss:0.029, train_loss:0.011
# Epoch 44, val_loss:0.032, train_loss:0.011
# Epoch 45, val_loss:0.030, train_loss:0.011
# Epoch 46, val_loss:0.028, train_loss:0.010
# Epoch 47, val_loss:0.031, train_loss:0.010
# Epoch 48, val_loss:0.027, train_loss:0.011
# Epoch 49, val_loss:0.028, train_loss:0.012
# Epoch 50, val_loss:0.030, train_loss:0.013
# Epoch 51, val_loss:0.026, train_loss:0.010
# Epoch 52, val_loss:0.028, train_loss:0.012
# Epoch 53, val_loss:0.031, train_loss:0.011
# Epoch 54, val_loss:0.029, train_loss:0.011
# Epoch 55, val_loss:0.026, train_loss:0.013
# Epoch 56, val_loss:0.029, train_loss:0.012
# Epoch 57, val_loss:0.025, train_loss:0.010
# Epoch 58, val_loss:0.025, train_loss:0.008
# Epoch 59, val_loss:0.028, train_loss:0.009
# Epoch 60, val_loss:0.030, train_loss:0.012
# Epoch 61, val_loss:0.028, train_loss:0.011
# Epoch 62, val_loss:0.030, train_loss:0.009
# Epoch 63, val_loss:0.031, train_loss:0.013
# Epoch 64, val_loss:0.030, train_loss:0.007
# Epoch 65, val_loss:0.032, train_loss:0.008
# Epoch 66, val_loss:0.032, train_loss:0.008
# Epoch 67, val_loss:0.031, train_loss:0.007
# Epoch 68, val_loss:0.031, train_loss:0.010
# Epoch 69, val_loss:0.032, train_loss:0.008
# Epoch 70, val_loss:0.030, train_loss:0.006
# Epoch 71, val_loss:0.030, train_loss:0.008
# Epoch 72, val_loss:0.031, train_loss:0.009
# Epoch 73, val_loss:0.027, train_loss:0.007
# Epoch 74, val_loss:0.030, train_loss:0.010
# Epoch 75, val_loss:0.029, train_loss:0.005
# Epoch 76, val_loss:0.031, train_loss:0.010
# Epoch 77, val_loss:0.033, train_loss:0.005
# Epoch 78, val_loss:0.032, train_loss:0.006
# Epoch 79, val_loss:0.030, train_loss:0.006
# Epoch 80, val_loss:0.028, train_loss:0.003
# Epoch 81, val_loss:0.031, train_loss:0.006
# Epoch 82, val_loss:0.031, train_loss:0.006
# Epoch 83, val_loss:0.031, train_loss:0.004
# Epoch 84, val_loss:0.030, train_loss:0.006
# Epoch 85, val_loss:0.029, train_loss:0.007
# Epoch 86, val_loss:0.030, train_loss:0.005
# Epoch 87, val_loss:0.029, train_loss:0.006
# Epoch 88, val_loss:0.029, train_loss:0.004
# Epoch 89, val_loss:0.027, train_loss:0.003
# Epoch 90, val_loss:0.023, train_loss:0.005
# Epoch 91, val_loss:0.023, train_loss:0.004
# Epoch 92, val_loss:0.031, train_loss:0.002
# Epoch 93, val_loss:0.030, train_loss:0.009
# Epoch 94, val_loss:0.027, train_loss:0.009
# Epoch 95, val_loss:0.027, train_loss:0.002
# Epoch 96, val_loss:0.030, train_loss:0.003
# Epoch 97, val_loss:0.030, train_loss:0.004
# Epoch 98, val_loss:0.028, train_loss:0.003
# Epoch 99, val_loss:0.027, train_loss:0.002
# Epoch 100, val_loss:0.030, train_loss:0.003
# Epoch 101, val_loss:0.029, train_loss:0.003
# Epoch 102, val_loss:0.027, train_loss:0.001
# Epoch 103, val_loss:0.030, train_loss:0.004
# Epoch 104, val_loss:0.028, train_loss:0.004
# Epoch 105, val_loss:0.029, train_loss:0.005
# Epoch 106, val_loss:0.027, train_loss:0.004
# Epoch 107, val_loss:0.030, train_loss:0.003
# Epoch 108, val_loss:0.030, train_loss:0.001
# Epoch 109, val_loss:0.028, train_loss:0.003
# Epoch 110, val_loss:0.030, train_loss:0.002
# Epoch 111, val_loss:0.029, train_loss:0.003
# Epoch 112, val_loss:0.030, train_loss:0.001
# Epoch 113, val_loss:0.030, train_loss:0.001
# Epoch 114, val_loss:0.028, train_loss:0.002
# Epoch 115, val_loss:0.029, train_loss:0.005
# Epoch 116, val_loss:0.031, train_loss:0.002
# Epoch 117, val_loss:0.031, train_loss:0.000
# Epoch 118, val_loss:0.031, train_loss:0.000
# Epoch 119, val_loss:0.031, train_loss:0.000
# Epoch 120, val_loss:0.031, train_loss:0.000
# Epoch 121, val_loss:0.031, train_loss:0.000
# Epoch 122, val_loss:0.031, train_loss:0.000
# Epoch 123, val_loss:0.031, train_loss:0.000
# Epoch 124, val_loss:0.031, train_loss:0.000
# Epoch 125, val_loss:0.031, train_loss:0.000
# Epoch 126, val_loss:0.031, train_loss:0.000
# Epoch 127, val_loss:0.031, train_loss:0.000
# Epoch 128, val_loss:0.031, train_loss:0.000
# Epoch 129, val_loss:0.031, train_loss:0.000
# Epoch 130, val_loss:0.031, train_loss:0.000
# Epoch 131, val_loss:0.031, train_loss:0.000
# Epoch 132, val_loss:0.031, train_loss:0.000
# Epoch 133, val_loss:0.031, train_loss:0.000
# Epoch 134, val_loss:0.031, train_loss:0.000
# Epoch 135, val_loss:0.031, train_loss:0.000
# Epoch 136, val_loss:0.031, train_loss:0.000
# Epoch 137, val_loss:0.031, train_loss:0.000
# Epoch 138, val_loss:0.031, train_loss:0.000
# Epoch 139, val_loss:0.031, train_loss:0.000
# Epoch 140, val_loss:0.031, train_loss:0.000
# Epoch 141, val_loss:0.031, train_loss:0.000
# Epoch 142, val_loss:0.031, train_loss:0.000
# Epoch 143, val_loss:0.031, train_loss:0.000
# Epoch 144, val_loss:0.031, train_loss:0.000
# Epoch 145, val_loss:0.031, train_loss:0.000
# Epoch 146, val_loss:0.031, train_loss:0.000
# Epoch 147, val_loss:0.031, train_loss:0.000
# Epoch 148, val_loss:0.031, train_loss:0.000
# Epoch 149, val_loss:0.031, train_loss:0.000
# Epoch 150, val_loss:0.031, train_loss:0.000
# Epoch 151, val_loss:0.027, train_loss:0.009
# Epoch 152, val_loss:0.029, train_loss:0.003
# Epoch 153, val_loss:0.029, train_loss:0.007
# Epoch 154, val_loss:0.028, train_loss:0.000
# Epoch 155, val_loss:0.028, train_loss:0.000
# Epoch 156, val_loss:0.028, train_loss:0.000
# Epoch 157, val_loss:0.028, train_loss:0.000
# Epoch 158, val_loss:0.028, train_loss:0.000
# Epoch 159, val_loss:0.028, train_loss:0.000
# Epoch 160, val_loss:0.028, train_loss:0.000
# Epoch 161, val_loss:0.028, train_loss:0.000
# Epoch 162, val_loss:0.028, train_loss:0.000
# Epoch 163, val_loss:0.028, train_loss:0.000
# Epoch 164, val_loss:0.028, train_loss:0.000
# Epoch 165, val_loss:0.028, train_loss:0.000
# INFO: Early stopping
# Epoch 166, val_loss:0.028, train_loss:0.000
# labels shape torch.Size([1043])
# finished linear training
# finished linear training

# %%
# for subsampling_criteria in ['stratified', 'reduce_negatives', 'reduce_positives', ]:
#     for percentage in [20, 40, 60, 80, 100]:
#         train_data_percentage = percentage / 100
#         args = {
#                                 'subsampling_strategy':{
#                                     'name': subsampling_criteria,
#                                     'percentage': train_data_percentage
#                                 },
#                                 'optimizer':{
#                                     'kind': 'RMSprop',
#                                     'learning_rate': 1e-6,
#                                     'momentum': 0.6
#                                 },
#                                 'loss_function': {
#                                         'kind': 'NTXentLoss',
#                                         'temperature': 0.07,
#                                         'mining': {
#                                             'positives': None,
#                                             'negatives': None
#                                         }
#                                 },
#                                 'number_folds': 5,
#                                 'backbone_name': 'MertashMultiParametricNetworkV2',
#                                 'data': 'mertash',
#                                 'sequence_embedding_features': 512,
#                                 'target_shape': (12, 32, 32),
#                                 'batch_size': 32,
#                                 'epochs': 5000,
#                             }
#         run_k_fold(args)

# %% [markdown]
# # VISUALIZANDO EMBEBIDOS

# %% [markdown]
# # CB3()

# %%
 args = {
                        'subsampling_strategy':{
                            'name': 'subsampling_criteria',
                            'percentage': 'train_data_percentage'
                        },
                        'optimizer':{
                            'kind': 'RMSprop',
                            'learning_rate': 1e-6,
                            'momentum': 0.6
                        },
                        'loss_function': {
                                'kind': 'TripletLoss',
                                'temperature': 0.07,
                                'mining': {
                                    'positives': 'easy',
                                    'negatives': 'semihard'
                                }
                        },
                        'number_folds': 5,
                        'backbone_name': 'Contrastive_CB3',
                        'data': 'mertash',
                        'sequence_embedding_features':18432,
                        'target_shape': (12, 32, 32),
                        'batch_size': 32,
                        'epochs': 5000,
                    }

# %%
#'/home/jaolmosr_pupils/Cesar/Experiments/'
# weights_path = '/data/Experiments/models/mertash_contrastive_fold_2.pt'
weights_path = '/data/Experiments_Contrastive_CB3/models/mertash_contrastive_fold_2.pt'
model = Contrastive_CB3(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
model.load_state_dict(torch.load(weights_path))

# %%
x_train, x_validation ,y_train, y_validation, ids_train, ids_val = get_fold_of_data(2)

val_data = DatasetManagement(x_validation, y_validation)
train_data = DatasetManagement(x_train, y_train)
test_dataset = val_data

# %%
val_loader = torch.utils.data.DataLoader(
    dataset = test_dataset,
    shuffle = False,
    batch_size = args['batch_size'],
    pin_memory=False
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# Inicializar listas vacías para almacenar las salidas y las etiquetas
all_outputs = []
all_labels = []

with torch.no_grad():
    model.eval()
    model.to(device)
    val_loss = 0.0
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        for j in range(len(inputs)):
            inputs[j] = inputs[j].to(device).type(torch.float)
        labels = labels.to(device)
        outputs = model(inputs)
        outputs = torch.nn.functional.normalize(outputs, p=2.0)
        # Almacenar las salidas y las etiquetas en las listas
        all_outputs.append(outputs.cpu().detach().numpy())
        all_labels.append(labels.cpu().numpy())

# Concatenar todas las salidas y las etiquetas
all_outputs = np.concatenate(all_outputs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

# Aplicar PCA
pca = PCA(n_components=2)
reduced = pca.fit_transform(all_outputs)

# Graficar los datos reducidos, coloreando por etiqueta
scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c=all_labels)
plt.legend(*scatter.legend_elements())
plt.show()

# Imprimir el número de puntos graficados
print(f'Número de puntos graficados: {len(all_outputs)}')

# %%
pca = PCA(n_components=3)  # Inicializar PCA con 3 componentes
reduced = pca.fit_transform(all_outputs)  # Reducir la dimensionalidad de los datos

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar los datos reducidos
scatter = ax.scatter(reduced[:, 0], reduced[:, 1], reduced[:, 2], c=all_labels)

# Definir las leyendas
leyendas = ['maligno', 'benigno']

# Pasar las leyendas al método legend()
plt.legend(handles=scatter.legend_elements()[0], labels=leyendas)

plt.show()

# %% [markdown]
# # CB3_SPD

# %%
args = {
        'subsampling_strategy':{
            'name': 'subsampling_criteria',
            'percentage': 'train_data_percentage'
        },
        'optimizer':{
            'kind': 'Mix_RMSprop',
            'learning_rate': 1e-6,
            'momentum': 0.6
        },
        'loss_function': {
                'kind': 'NTXentLoss',
                'temperature': 0.07,
                'mining': {
                    'positives': 'easy',
                    'negatives': 'semihard'
                }
        },
        'number_folds': 5,
        'backbone_name': 'Contrastive_CB3_SPD_1Bire',
        'data': 'mertash',
        'sequence_embedding_features': 136,
        'target_shape': (12, 32, 32),
        'batch_size': 32,
        'epochs': 5000,
    }

# %%
weights_path = '/data/Experiments/models/mertash_contrastive_fold_5.pt'
model = Contrastive_CB3_SPD_1Bire(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
model.load_state_dict(torch.load(weights_path))

# %%
x_train, x_validation ,y_train, y_validation, ids_train, ids_val = get_fold_of_data(2)

val_data = DatasetManagement(x_validation, y_validation)
train_data = DatasetManagement(x_train, y_train)
test_dataset = val_data

# %%
val_loader = torch.utils.data.DataLoader(
    dataset = test_dataset,
    shuffle = False,
    batch_size = args['batch_size'],
    pin_memory=False
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# Inicializar listas vacías para almacenar las salidas y las etiquetas
all_outputs = []
all_labels = []

with torch.no_grad():
    model.eval()
    model.to(device)
    val_loss = 0.0
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        for j in range(len(inputs)):
            inputs[j] = inputs[j].to(device).type(torch.float)
        labels = labels.to(device)
        outputs = model(inputs)
        outputs = torch.nn.functional.normalize(outputs, p=2.0)
        # Almacenar las salidas y las etiquetas en las listas
        all_outputs.append(outputs.cpu().detach().numpy())
        all_labels.append(labels.cpu().numpy())

# Concatenar todas las salidas y las etiquetas
all_outputs = np.concatenate(all_outputs, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

# Aplicar PCA
pca = PCA(n_components=2)
reduced = pca.fit_transform(all_outputs)

# Graficar los datos reducidos, coloreando por etiqueta
scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c=all_labels)
plt.legend(*scatter.legend_elements())
plt.show()

# Imprimir el número de puntos graficados
print(f'Número de puntos graficados: {len(all_outputs)}')

# %%
pca = PCA(n_components=3)  # Inicializar PCA con 3 componentes
reduced = pca.fit_transform(all_outputs)  # Reducir la dimensionalidad de los datos

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar los datos reducidos
scatter = ax.scatter(reduced[:, 0], reduced[:, 1], reduced[:, 2], c=all_labels, alpha=0.3)

# Definir las leyendas
leyendas = ['maligno', 'benigno']

# Pasar las leyendas al método legend()
plt.legend(handles=scatter.legend_elements()[0], labels=leyendas)

plt.show()
